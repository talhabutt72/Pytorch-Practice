# %%
import torch
import torch.nn as nn

# %%
# from torch._C import float64
x = torch.randn(2,4,10, dtype = torch.float32)
x
# Out:
# tensor([[[-0.6440, -0.4432, -0.3209, -0.3882,  1.8231,  0.3889, -0.9788,
#           -1.0039,  1.4989,  0.4868],
#          [ 0.2329,  0.2807,  2.3320,  0.1542, -0.5059, -1.2118, -0.3479,
#           -0.3853,  0.8534,  2.7208],
#          [ 0.9255, -0.0093, -0.7999, -0.2109,  0.0426,  1.3823, -0.0588,
#            0.3737,  0.3740,  0.2088],
#          [-0.0635, -0.2195,  0.8536, -1.2862, -1.1756,  0.7888,  0.8671,
#            0.5586, -1.7090,  1.2644]],
#
#         [[ 0.6448,  1.3467,  0.0170,  0.7287, -0.3450, -1.7629, -0.5636,
#            0.3866,  2.4218,  1.0837],
#          [ 1.2732, -1.0825,  1.2603,  0.0759,  0.2478, -0.8234,  0.1923,
#            0.4110,  0.4308,  0.0098],
#          [ 0.5090, -0.0117, -0.8345, -0.7072, -0.3979, -0.7040,  0.1892,
#            0.2508,  1.7290,  0.7995],
#          [-0.2036,  1.1100, -0.2325,  0.9872,  2.2293,  0.8129,  0.1886,
#            1.3045, -0.6998, -0.7232]]])

# %%
lstm = nn.LSTM(10, 32, batch_first = True)

# %%
c_0 = torch.zeros(1, 2, 32, dtype = torch.float32)
h_0 = torch.zeros(1, 2, 32, dtype = torch.float32)

# %%
output, (c_final, h_final) = lstm(x, (c_0, h_0))

# %%
# Out:
# All hidden states: torch.Size([2, 4, 32])
